# %% [markdown]
# #📌 **supply-chain-late-delivery-risk**
#
# ML project to predict late delivery risk using decision-time information.
#
# # **Project Overview**
#
# This project predicts whether a customer order is at risk of late delivery using Machine Learning. The model uses only decision-time information to avoid data leakage and support early decision-making.

# %%
import zipfile
import os

# Unzip the dataset
zip_path = '/content/DataCoSupplyChaindataset.zip'
extract_path = '/content/dataco_supply_chain'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the extracted files
os.listdir(extract_path)
# Out:
# ['DataCoSupplyChainDataset.csv']

# %% [markdown]
# #📌 **DataCoSupplychainDataset.csv**

# %%
import pandas as pd

# Load the main dataset (assuming typical naming from this dataset source)
# If the filename differs, we can adjust based on the output of the previous cell
csv_path = os.path.join(extract_path, 'DataCoSupplyChainDataset.csv')

try:
    df = pd.read_csv(csv_path, encoding='ISO-8859-1')
    display(df.head())
    print(df.info())
except Exception as e:
    print(f"Error loading CSV: {e}")
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...
